# %%
import pandas as pd
import glove
from gensim.models import Word2Vec
import numpy as np
from tqdm import tqdm
from sklearn.metrics.pairwise import cosine_similarity
from matplotlib import pyplot as plt
from collections import Counter
from scipy.sparse import csr_matrix
from gensim.models import LdaModel
from gensim.corpora.dictionary import Dictionary
import pickle

# %% [markdown]
# # Load the data

# %%
df=pd.read_pickle('/data/nlp_proj/all_comments_per_writer_df2.pkl')

# %%
print("The shape of the data is:{0}.\n{1} is the total number of comments,\nand {2} is the number of columns (features) I collected for each comment.".format(df.shape,df.shape[0],df.shape[1]))
print("\nThe columns of the data are:{}".format(list(df.columns)))
print("\nNumber of unique articles:{}".format(df.article_id.nunique()))
print("\nNumber of unique writers:{}".format(df.name.nunique()))
print('\n')
print("An example to five random rows in the data:\n")
df.sample(5)
# Out:
# The shape of the data is:(3439654, 15).
# 3439654 is the total number of comments,
# and 15 is the number of columns (features) I collected for each comment.
#
# The columns of the data are:['name', 'comment_number', 'comment_to', 'comments', 'comments_body', 'maybe_signature', 'date', 'time', 'original_comment_to', 'article_id', 'datetime', 'clean_comments', 'clean_comments_body', 'comment_to_name', 'original_comment_to_name']
#
# Number of unique articles:113619
#
# Number of unique writers:4439
#
#
# An example to five random rows in the data:
#             name  comment_number  comment_to  \
# 1         tsvika               1           0
# 45      ירבה דעת              39          12
# 71      DOMINO D              57          54
# 44  דני מכפר סבא              13           0
# 81   זאביק השועל             121          19
#
#                                              comments  \
# 1                                בלון גז, מספר פצועים
# 45                                       תורו ברשימה?
# 71                                             ממש לא
# 44  הפיתרון: להוציא מכרז לחברה מחו''ל לצורך ההקמה....
# 81                                             בדיוק!
#
#                                         comments_body  \
# 1
# 45                                  🇮🇱 עם ישראל חי 🇮🇱
# 71  השיר של אסלנד לא בולט בכלל .בלדה משמימה יש עוד...
# 44  "החלימה" http://bloogerisrael.blogspot.com/201...
# 81
#
#                                       maybe_signature      date   time  \
# 1                                                      20.06.18  12:19
# 45                                  🇮🇱 עם ישראל חי 🇮🇱  28.07.18  19:15
# 71                                                     03.05.18  18:17
# 44  "החלימה" http://bloogerisrael.blogspot.com/201...  23.08.18  21:23
# 81                                                     11.08.18  07:56
#
#     original_comment_to  article_id            datetime  \
# 1                   0.0      481593 2018-06-20 12:19:00
# 45                 12.0      490605 2018-07-28 19:15:00
# 71                 54.0      469537 2018-05-03 18:17:00
# 44                  0.0      496889 2018-08-23 21:23:00
# 81                 19.0      493848 2018-08-11 07:56:00
#
#                                        clean_comments  \
# 1                                 בלון גז מספר פצועים
# 45                                        תורו ברשימה
# 71                                             ממש לא
# 44  הפיתרון להוציא מכרז לחברה מחו ל לצורך ההקמה גו...
# 81                                              בדיוק
#
#                                   clean_comments_body comment_to_name  \
# 1                                                        החדשות החמות
# 45                                        עם ישראל חי     beni_israel
# 71  השיר של אסלנד לא בולט בכלל בלדה משמימה יש עוד ...             669
# 44  החלימה http bloogerisrael blogspot com 2018 08...        gold1980
# 81                                                             דוידוב
#
#    original_comment_to_name
# 1              החדשות החמות
# 45              beni_israel
# 71                      669
# 44                 gold1980
# 81                   דוידוב

# %% [markdown]
# The "article id" is the id of the article, and you can see the article in the link: https://rotter.net/forum/scoops1/ARTICLE_ID.shtml  where ARTICLE_ID should be replaced with the actual article_id.

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Defining Thresholds

# %%
TH_comments=90
TH_articles=50

# %% [markdown]
# ### Aplying the Thresholds:
# <p> Remove users with less than <b>TH_comments</b> comments in <b>TH_comments</b> unique articles, and articles with less than <b>TH_article</b> comments:<p>

# %%
print("number of users before applying the threshold : {}".format(df.name.nunique()))
relevant_names=df.groupby('name')['article_id'].nunique()
relevant_names.sort_values(ascending=False, inplace=True)
relevant_names=relevant_names.index[relevant_names>TH_comments]
df=df[df.name.isin(relevant_names)]
print("number of users after applying the threshold : {}".format(df.name.nunique()))
# Out:
# number of users before applying the threshold : 4439
# number of users after applying the threshold : 2335

# %%
print("number of articles before applying the threshold : {}".format(df.article_id.nunique()))
relevant_articles=df.groupby('article_id').size()
relevant_articles=relevant_articles.index[relevant_articles>TH_articles]
df=df[df.article_id.isin(relevant_articles)]
print("number of articles after applying the threshold : {}".format(df.article_id.nunique()))
# Out:
# number of articles before applying the threshold : 113432
# number of articles after applying the threshold : 19078

# %% [markdown]
# <p> So, we are left with relatively about a half of our original users, and about 1/6 of our original articles, <br> but we have to remember that we are left with the most "fruitful" users,<br> and with the most interesting (in terms of public interest) articles</p>

# %% [markdown]
# # adding a unique identifier randomly to nicknames

# %% [markdown]
# <p> In order to be able to test the quality of my results,<br>I'm going to add a suffix to usernames in random (p=0.5).<br> The suffix would be "#" at the end of the nickname.<br> In other words, if someones username is "John", <br>in about a half of the articles his name will be "John"<br> and in about another half of the articles his name will be "John#". </p>

# %%
all_articles=df.article_id.unique()

# %%
np.random.seed(47)  #for reproducability
all_dfs=[]
for a in tqdm(all_articles):
    curr_df=df[df.article_id==a]
    curr_names=curr_df.name.unique()
    sampled_names=np.random.choice(curr_names,size=len(curr_names)//2,replace=False)
    curr_df['name']=np.where(curr_df.name.isin(sampled_names),curr_df.name.str.strip('#')+'#',curr_df.name)
    curr_df['comment_to_name']=np.where(curr_df.comment_to_name.isin(sampled_names),curr_df.comment_to_name.str.strip('#')+'#',curr_df.comment_to_name)
    curr_df['original_comment_to_name']=np.where(curr_df.original_comment_to_name.isin(sampled_names),curr_df.original_comment_to_name.str.strip('#')+'#',curr_df.original_comment_to_name)
    if not all_dfs:
        all_dfs=[curr_df]
    else:
        all_dfs.append(curr_df)
this_df=pd.concat(all_dfs)
pd.to_pickle(this_df,'/data/nlp_proj/all_comments_per_writer_df_with_hash.pkl')
# Out:
#   0%|          | 0/19078 [00:00<?, ?it/s]/home/binyamine/.conda/envs/standard_anaconda/lib/python3.5/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /home/binyamine/.conda/envs/standard_anaconda/lib/python3.5/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/binyamine/.conda/envs/standard_anaconda/lib/python3.5/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# 100%|██████████| 19078/19078 [1:54:06<00:00,  1.75it/s]

# %%
df=pd.read_pickle('/data/nlp_proj/all_comments_per_writer_df_with_hash.pkl')

# %% [markdown]
# # Train Word2Vec

# %% [markdown]
# ### creating the "sentences" - chained nicknames for each article

# %%
small_df=df[['name','article_id']]
article_id_u = sorted(df.article_id.unique())
sentences=[]
for a in tqdm(article_id_u):
    sentence = small_df[small_df.article_id == a]['name'].str.cat(sep=',').split(',')
    sentences.append(sentence)
# Out:
# 100%|██████████| 19078/19078 [00:40<00:00, 468.06it/s]

# %% [markdown]
# ### running the model itself

# %%
model=Word2Vec(sentences=sentences,size=30,window=400,min_count=70, workers=32)
X=model[model.wv.vocab]
names=model.wv.vocab.keys()
names_df=pd.DataFrame(X)
names_df.index=names
names_df.to_csv('/data/nlp_proj/all_names_hashed_vecs_size_30_min_count_70.csv')
# Out:
# /home/binyamine/.conda/envs/standard_anaconda/lib/python3.5/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %% [markdown]
# ## Analyzing the results

# %% [markdown]
# ### creating similarity matrix between the names

# %%
p=cosine_similarity(X)
users_df=pd.DataFrame(p,columns=names, index=names)
users_df.to_csv('word2vec_similarity_all_users_gt_70.csv')

# %%
users_df=pd.read_csv('word2vec_similarity_all_users_gt_70.csv') #after we already created the df we simply load it
users_df=users_df.set_index(users_df.columns[0])

# %%
print(users_df.shape)
users_df.head(3)
# Out:
# (3514, 3514)
#                 תכלת דומה לים#     רוסו#  CheshireCat69#  מהיהודים   Hermon#  \
# Unnamed: 0
# תכלת דומה לים#        1.000000 -0.074395       -0.160330 -0.089181  0.316900
# רוסו#                -0.074395  1.000000        0.006772 -0.146821 -0.260288
# CheshireCat69#       -0.160330  0.006772        1.000000  0.211595  0.033611
#
#                 זאביק השועל#      בראל    יריחו3    marko#   אניהיא#  ...  \
# Unnamed: 0                                                            ...
# תכלת דומה לים#      0.096250  0.150296 -0.025004 -0.017811 -0.111716  ...
# רוסו#               0.172274  0.037877 -0.068024  0.142582  0.164461  ...
# CheshireCat69#      0.218270 -0.211127 -0.071285  0.288324  0.163757  ...
#
#                   איש-קש       בעז     Ben1#    popay#  רוכב ערבות   וו ווי#  \
# Unnamed: 0
# תכלת דומה לים#  0.261849  0.359232  0.003672  0.028435    0.322437  0.025839
# רוסו#           0.123769  0.161645 -0.096098  0.080987   -0.080909  0.014858
# CheshireCat69# -0.185337  0.272093  0.113910 -0.120093   -0.106033  0.168780
#
#                    בראל#    brosh#  דרומייי#   הדרקון#
# Unnamed: 0
# תכלת דומה לים#  0.039522 -0.039706  0.240161 -0.302293
# רוסו#           0.095964 -0.211689 -0.134291 -0.244979
# CheshireCat69# -0.283318 -0.168962  0.087750  0.170193
#
# [3 rows x 3514 columns]

# %% [markdown]
# ### checking the rank of each "created" nick against the original nick

# %% [markdown]
# <p> As explained before, I took each nick, and about half of the time I left the nick as is, and about another half of the times I appended "#" to the nick. <br>
# What I am checking now is, in the similarity measure table I created (that uses cosine-similarity),<br>
# what will be the average rank of each "created" nick to the original nick. <br>
# For sure, the similarity of a nick to itself will be the highest, the rank will be 0,  and the similarity will always be 1. <br>
# But as we know that the original nick and the created nick (the #-appended nick) are basically the same person,<br> if the method works well the average rank of the #-appended nick should be low.
# As there are 3514 nicks (1757 original nicks and 1757 "fake" nicks that corresponds to the original nicks) - a totally random method will yield an average rank of about 1757 (the average case). As close as the average rank would be to 0 - as good as we will know the method is.

# %%
original_columns=[c for c in users_df.columns if not c.endswith('#')]

# %%
all_indexes=[]
original_names=[]
for o_c in tqdm(original_columns):
    try:
        curr_series=users_df[o_c]
        curr_series=users_df[o_c].sort_values(ascending=False)
        curr_index=curr_series.index.get_loc(o_c+'#')
        all_indexes.append(curr_index)
        original_names.append(o_c)
    except:
        print(o_c)
similarity_series=pd.Series(all_indexes, index=original_names)
# Out:
#   8%|▊         | 144/1761 [00:00<00:02, 707.32it/s]
# w00t
# בית חבד
# ענק השפלה
# eyalsh
# פיפו
# Picho
# egel
# האיש שבקיר
# daniel68
# shush
#  16%|█▋        | 289/1761 [00:00<00:02, 714.14it/s]
# עםהנצח
# פינוקיו
# בנימין
# The Last One
# סנוב
# יוסף חיים
# אבי מהצפון
# askobilv
# Dking
#  25%|██▍       | 436/1761 [00:00<00:01, 721.69it/s]
# הקלריקל
# טוני
# שחורי
# Gavrik
# רוני
# moshe555
# יצמח פורקניה
# Tachlit
# חצילון
# אייל_ביבי
# עובדתי
# אידית77
#  33%|███▎      | 583/1761 [00:00<00:01, 726.26it/s]
# LiavAvraham
# היפוקסיה
# טרנספר
# Masoolin2
# הדגזהב
# משה צעירי
# angular
# אסד
# איש המדבר
# הלוחש לסוסים
#  46%|████▌     | 803/1761 [00:01<00:01, 724.69it/s]
# Max555
# mwg
# TecNodRom
# זוז
# oranus
# יהודי_ישראלי
# ברוש
# מסי פרגוסון
# jointil
#  54%|█████▎    | 946/1761 [00:01<00:01, 716.00it/s]
# המיוחד
# חוד החנית
# PaPaPanda
# השומר הצעיר
# החלילן
# סבי
#  62%|██████▏   | 1093/1761 [00:01<00:00, 723.86it/s]
# Bostonterrier
# Makelove
# danielc
# חיריק
# ירושלמי02
# אריאל1
#  79%|███████▉  | 1390/1761 [00:01<00:00, 731.30it/s]
# זונטיק
# שרלוק הולמס
# israel67
# מגדלהשן
# מוסקבה
# Rubicon
# פרש צפוני
# eliko
#  87%|████████▋ | 1537/1761 [00:02<00:00, 728.15it/s]
# Idan
# blue eyes
# צ'ארלי דלתא
# היפכא מסתברא
# רגב טל
# פלוני
#  96%|█████████▌| 1684/1761 [00:02<00:00, 728.21it/s]
# בוגו
# בר-יוחאי
# טוקסידו צחור
# שלג לבן
# yosef13
# simonik
# נפתלי
# דבר והיפוכו
# 100%|██████████| 1761/1761 [00:02<00:00, 724.96it/s]
# לא פה ולא פה
# איש-קש
# רוכב ערבות

# %%
print("mean rank: {}".format(similarity_series.mean()))
print("median rank: {}".format(similarity_series.median()))
print("75% quantile: {}".format(similarity_series.quantile(0.75)))
print("90% quantile: {}".format(similarity_series.quantile(0.9)))
# Out:
# mean rank: 188.00836320191158
# median rank: 22.0
# 75% quantile: 129.75
# 90% quantile: 479.70000000000005

# %% [markdown]
# <p><b> We see that the results are not bad at all! out of more than 3k nicknames, 50% of the ranks are smaller than 22, 75% of the ranks are smaller than 130, and 90% are smaller than 480!</b> </p>

# %% [markdown]
# ### histogram of the results

# %%
similarity_series.hist(bins=100,histtype='step')
#plt.title('Word2Vec ranks distribution')
plt.xlabel('rank')
_=plt.ylabel('frequency')

# %%
Counter(similarity_series).most_common(20)
# Out:
# [(1, 262),
#  (2, 102),
#  (3, 80),
#  (6, 46),
#  (4, 39),
#  (8, 37),
#  (5, 35),
#  (7, 30),
#  (12, 27),
#  (9, 23),
#  (11, 23),
#  (10, 22),
#  (13, 17),
#  (29, 17),
#  (17, 15),
#  (15, 14),
#  (16, 14),
#  (14, 12),
#  (18, 12),
#  (23, 12)]

# %% [markdown]
# <b>262 of the pairs, about 1/7, were ranked first, using the word2vec method!</b>

# %% [markdown]
# # LDA Analysis

# %% [markdown]
# ## loading the data

# %%
df2=pd.read_pickle('/data/nlp_proj/all_comments_per_writer_df_with_hash.pkl')

# %% [markdown]
# <p> For the LDA process, we will need to clean the text as much as we can. I already cleaned it in the scraping process, but in rotter.net there is a <b>signature</b> - a short sentence or phrase that can be added to each message. This can of course add a lot of noise - so I would like to get rid of the signatures. In the process of the scraping I already marked "candidates" for signatures, base on HTML/CSS elements etc., but here I would like to get rid of the signatures completely.</p>

# %%
df2
# Out:
#                name  comment_number  comment_to  \
# 0              Mr W               0          -1
# 1         פובליציסט               1           0
# 2               joe               2           0
# 3              חתול               4           2
# 4          Starback               7           2
# 5          Starback               3           0
# 7        צבי_ישראל#              51          41
# 9        צבי_ישראל#              56          54
# 10         SpinozaB              59          56
# 11       צבי_ישראל#              60          59
# 12        Reflektor               5           0
# 13            וומבו              29           5
# 14      intelligent               6           0
# 15     להכות בברזל#              11           6
# 16          לבנהרץ#              12          11
# 17   אניאנונימיאני#              58          11
# 18        News_Max#               8           0
# 19          ABRAMOV               9           0
# 20         goproei#              10           0
# 21             פיטר              13           0
# 22      NowsTheTime              16           0
# 23      Gill Bates#              27          16
# 24           yamin#              17           0
# 25          dilbert              18           0
# 26             Mr W              68          18
# 27       פרה אדומה#              19           0
# 28           dnmnd#              43          19
# 29     קורא באספרסו              20           0
# 30         raceway#              21           0
# 31          ביריון#              22           0
# ..              ...             ...         ...
# 122       פרה אדומה              70          66
# 123        Reddish#              75          66
# 124             Idf              76          75
# 125        קפטן הוק              77          76
# 126             Idf              80          77
# 127          yansop              88          80
# 128             Idf             104          88
# 129        קפטן הוק             112         104
# 130             Idf             113         112
# 131      אנא כורדי#              94          66
# 132          פלומה#              69           0
# 133           em28#              71           0
# 134        daraten#             135          71
# 135            איתי              79           0
# 136         pure_sp              84           0
# 137        scapula#             134          84
# 138   הא כספא עניא#              91           0
# 139         me אני#              97          91
# 140           BEBO#              96           0
# 141       Tinshemet              98          96
# 142           galt#             100           0
# 144        Rubicon#             138         101
# 145    bear yogurt#             102           0
# 146           יואב#             105           0
# 147           galt#             106         105
# 148      יגאל פת-אל             114           0
# 149          עפרנח#             118         114
# 150       dave2000#             116           0
# 151           כינרת             117         116
# 152          סקפטי#             142           0
#
#                                               comments  \
# 0    מנהיג צפון קוריאה: כפתור גרעיני הותקן בשולחן ה...
# 1    ככה זה, קים מזמין הפצצה גרעינית, וטראמפ מזמין ...
# 2                       עכשיו צריך רק להפציץ את השולחן
# 3                                                גדולל
# 4                                                 חחחח
# 5    בעבר היו מטורפים שניסו וגם הצליחו להשמיד עמים ...
# 7                                       שכחת....צוללות
# 9                                לא הייתי מזלזל בצוללת
# 10   אתה חושב שפצצה אחת תשמיד את אמריקה... מקסימום ...
# 11                            לא להשמדה פיזית התכוונתי
# 12           כל עוד זה לא הותקן בשירותים שלו, אני רגוע
# 13                                                 חחח
# 14                          האיומים המאוד נקודתיים שלו
# 15   לא הציג יכולות? הטיל האחרון ששיגר הוכח כיכול ל...
# 16   בדיוק, ברור הרי שללא קייס ארה״ב היתה כבר אחרי ...
# 17   יש הבדל גדול בין פיצוץ מתקן גרעיני במנהרה לבין...
# 18                                               בדיחה
# 19                 מזכיר את דוקטור evil מאוסטין פווארס
# 20                                 שולחן העבודה במחשב?
# 21                                                 הנה
# 22   לא רק איומים: קים מאחל הצלחה לאולימפידאת הנכים...
# 23   ברור שיתמוך בנכים; הטילים שישגר יהרגו מיליונים...
# 24                                         אפשר תמונה?
# 25   שלא יתבלבל בין הכפתור של lunch והכפתור של launch.
# 26                                            חחח יפהה
# 27                                              טיפקס:
# 28                                 גם לי זה עלה לראש:)
# 29   מקווה שיש לו מצב ''נעילת שולחן'' כשהוא יוצא מה...
# 30   לפי איך שהוא נראה ראוי שישים את הכפתור בשולחן ...
# 31                  משוגע משוגע,  אבל עדיף להזהר ממנו.
# ..                                                 ...
# 122                               גם זה הרבה יותר מדי.
# 123                   לא רלווטי אם הוא יקבל 5, 6 או 7.
# 124  לא מאמין שיש ימני אמיתי שביום הבוחר מאחורי הפרגוד
# 125          פסיכולוגיה בגרוש. נתניהו לא ימין - עובדה.
# 126            צודק גנץ ימין . לפיד ימין . ליברמן ימין
# 127               מה זה ימין שפוי ומה זה ימין קיצוני ?
# 128                         אני בעד יד קשה מול האויבים
# 129                       ואתה מצביע למי? נתניהו? חחחח
# 130                  ליכוד , ימינה , אפילו יהדות התורה
# 131  מי שמכיר את השטח, ויוצאי חבר העמים, מבין שהוא ...
# 132  בוגר וקסנר נעדר... מעניין אם קיבל הוראה מהבוסי...
# 133  למכירה מצלמות לצילום בקלפיות חדשות באריזה,לפרט...
# 134  זה אף פעם לא ב.נ. עצמו - זה תמיד בן דוד או מקו...
# 135                          ככה זה כשלא יודעים לשלוט.
# 136                                  אם למישהו היה ספק
# 137                                 לא ברור לי הקו הזה
# 138                                   קארמה איז א ביץ׳
# 139                                             אכן!!!
# 140  ליברמן שלשום תמך בחוק, היום מתנגד.  קשקשן מארץ...
# 141                  מקביל ל''אשקול את הנושא'' של ביבי
# 142                                      הו הא מה קרה?
# 144  מטרתו לגרום להתכתשות שתעביר תעמולת 'הזייפנים נ...
# 145                              ערוץ הבידור... ובחינם
# 146  ראיתי את הפרצופים המעצבנים בוועדה המסדרת של חכ...
# 147                                     חחח, אשריך :))
# 148                                       טרגדיה ענקית
# 149                                 התכוונת לכחול לבן?
# 150  נתניהו נושם לרווחה, הוא לא באמת רוצה את החוק כ...
# 151  סוף סוף תגובה רצינית. הכל היה פרובוקציה כדי שש...
# 152                      צר לי שפולקמן עוזב. איש ערכי.
#
#                                          comments_body  \
# 0    מנהיג צפון קוריאה, קים ג'ון און, מתפאר שבשולחן...
# 1
# 2
# 3
# 4
# 5    אבל המטורף השמן הזה מצפון קוריאה עולה על כולם ...
# 7    או ליתר דיוק צוללת אחת לפי הפורסם - שגם אותה ל...
# 9    בפרט אם היא בקטע של משימה ''חד פעמית''-קמיקאזה...
# 10   במדבר י"ג, ל"ג: "..ונהי בעינינו כחגבים וכן היי...
# 11   יותר לעידן של פחד וחששותבדיוק כמו שאירופה עברה...
# 12
# 13                                   אכן, עצירות הורגת
# 14   עם צורה ועם הרבה צבע, מעלים את הסבירות כי אין ...
# 15   מצביעות בוודאות על יכולת גרעינית, גם פצצות מימ...
# 16
# 17
# 18                                  ליצן חצר לא מוצלח.
# 19   עוד רגע הוא מאיים שאם לא יתנו לו מיליון דולר ה...
# 20                                 בטח יש לו חלונות 95
# 21
# 22   הרודן אמר בנוסף שהוא ישתמש בגרעין רק במידה וצפ...
# 23   לכל חייהם.אז כדי להקדים תרופה למכה, הוא תומך ב...
# 24
# 25
# 26
# 27                            לחץ כאן לצפיה דרך יוטיוב
# 28
# 29   באמת, פסיכופת מושלם האיש הקטןבעולם מתוקן הוא ו...
# 30
# 31                            לחץ כאן לצפיה דרך יוטיוב
# ..                                                 ...
# 122    במבט לאחור, חוכמה בדיעבד זה בעצם דבר נורא טפשי.
# 123  אלא כמה מצביעי שמאל וכמה ימין הוא יגנוב. כרגע ...
# 124  ישלשל פתק של ליברמן בידיעה שהוא מקבל ממשלת שמא...
# 125                              צֶדֶק צֶדֶק תִּרְדֹּף
# 126  ובן גביר ראש הממשלה הבא .או לנו עם אחד כמו בן ...
# 127  מה שפוי בימין שאתה מייצגזה מענייןאתה בעד מסירת...
# 128  אני בעד למצוא פתרון למסתננים אני בעד למצוא פית...
# 129                              צֶדֶק צֶדֶק תִּרְדֹּף
# 130                              רק לא לבן גביר ולהקתו
# 131  אבל למה להרוס את כל הכיף!?תן לשמאל להתבשם בשטו...
# 132  אין לנו ארץ אחרת, מדינת ישראל תישאר יהודית ודמ...
# 133                           תתמודדו, הפועל יש רק אחת
# 134  הנה תראו איש משתגע, למה תביאו אותו אליי.  חסר ...
# 135
# 136  ליברמן -טיבי- לפיד בשיתוף פעולהליברמן בגוש השמ...
# 137  מה גורם לכם לחשוב שמצביעי ליברמן עילגים עד כדי...
# 138
# 139  ויש לך ניק מאד מאד מקורי   ואם נחרבנו ונחרב הע...
# 140            we are fed up with being ruled by goyim
# 141
# 142                       הגוש הימני-ציוני אכל אותה...
# 144  סביר שלא חשוב שהצעת החוק תעבור - רק הרעש התקשו...
# 145
# 146
# 147                 כמו לראות את זיו השכינה... תענוג..
# 148                        להיתקע עם מלאי של מצלמות...
# 149  כי הליכוד דיבר על תיעוד טלפוני.אגב, בבחירות הק...
# 150
# 151  הפתרון ההומאני לתושבי עזה - חיים נוחים באינדונזיה
# 152
#
#                                        maybe_signature      date   time  \
# 0    (adsbygoogle = window.adsbygoogle || []).push(...  01.01.18  02:59
# 1                                                       01.01.18  03:02
# 2                                                       01.01.18  03:18
# 3                                                       01.01.18  03:22
# 4                                                       01.01.18  03:24
# 5                                                       01.01.18  03:18
# 7    בברכה,  צבי ישראל    ... ארץ צבי כתיב בה (...)...  01.01.18  08:51
# 9    בברכה,  צבי ישראל    ... ארץ צבי כתיב בה (...)...  01.01.18  09:00
# 10   במדבר י"ג, ל"ג: "..ונהי בעינינו כחגבים וכן היי...  01.01.18  09:09
# 11   בברכה,  צבי ישראל    ... ארץ צבי כתיב בה (...)...  01.01.18  09:14
# 12                                                      01.01.18  03:22
# 13                                                      01.01.18  07:35
# 14                                                      01.01.18  03:23
# 15                                                      01.01.18  03:39
# 16                                                      01.01.18  03:41
# 17                                                      01.01.18  09:07
# 18                                                      01.01.18  03:25
# 19                                                      01.01.18  03:26
# 20                                                      01.01.18  03:30
# 21                                                      01.01.18  04:17
# 22                     הגיע זמן הגאולה והנה זה משיח בא  01.01.18  04:53
# 23                                                      01.01.18  07:24
# 24                                                      01.01.18  05:42
# 25                                                      01.01.18  06:05
# 26                                                      01.01.18  11:54
# 27   בורא עולם חנן אותך באינטלגנציה רגשית?  אל תהסס...  01.01.18  06:07
# 28                                                      01.01.18  08:37
# 29                                                      01.01.18  06:08
# 30                                                      01.01.18  06:08
# 31                                                      01.01.18  06:32
# ..                                                 ...       ...    ...
# 122    במבט לאחור, חוכמה בדיעבד זה בעצם דבר נורא טפשי.  09.09.19  13:18
# 123                                                     09.09.19  13:21
# 124                                                     09.09.19  13:22
# 125                              צֶדֶק צֶדֶק תִּרְדֹּף  09.09.19  13:24
# 126                                                     09.09.19  13:26
# 127  לא להסס! לגרש את כל המסתננים  ואת כל מי שפוגע ...  09.09.19  13:31
# 128                                                     09.09.19  13:49
# 129                              צֶדֶק צֶדֶק תִּרְדֹּף  09.09.19  14:19
# 130                                                     09.09.19  14:20
# 131                                                     09.09.19  13:37
# 132  אין לנו ארץ אחרת, מדינת ישראל תישאר יהודית ודמ...  09.09.19  13:17
# 133                           תתמודדו, הפועל יש רק אחת  09.09.19  13:18
# 134  הנה תראו איש משתגע, למה תביאו אותו אליי.  חסר ...  09.09.19  16:53
# 135                                                     09.09.19  13:25
# 136                                                     09.09.19  13:28
# 137                                                     09.09.19  16:45
# 138                                                     09.09.19  13:36
# 139  ואם נחרבנו ונחרב העולם עמנו ע"י שנאת חנם,נשוב ...  09.09.19  13:39
# 140            we are fed up with being ruled by goyim  09.09.19  13:39
# 141                                                     09.09.19  13:40
# 142                                                     09.09.19  13:41
# 144                                                     09.09.19  17:35
# 145                                                     09.09.19  13:46
# 146                                                     09.09.19  13:56
# 147                                                     09.09.19  13:57
# 148                                                     09.09.19  14:30
# 149  ישראל, כל מה שחטא היה גם כן ברצון ה' יתברך (רב...  09.09.19  14:58
# 150                                                     09.09.19  14:55
# 151  הפתרון ההומאני לתושבי עזה - חיים נוחים באינדונזיה  09.09.19  14:56
# 152                                                     09.09.19  18:19
#
#      original_comment_to  article_id            datetime  \
# 0                    0.0      445507 2018-01-01 02:59:00
# 1                    0.0      445507 2018-01-01 03:02:00
# 2                    0.0      445507 2018-01-01 03:18:00
# 3                    2.0      445507 2018-01-01 03:22:00
# 4                    2.0      445507 2018-01-01 03:24:00
# 5                    0.0      445507 2018-01-01 03:18:00
# 7                    3.0      445507 2018-01-01 08:51:00
# 9                    3.0      445507 2018-01-01 09:00:00
# 10                   3.0      445507 2018-01-01 09:09:00
# 11                   3.0      445507 2018-01-01 09:14:00
# 12                   0.0      445507 2018-01-01 03:22:00
# 13                   5.0      445507 2018-01-01 07:35:00
# 14                   0.0      445507 2018-01-01 03:23:00
# 15                   6.0      445507 2018-01-01 03:39:00
# 16                   6.0      445507 2018-01-01 03:41:00
# 17                   6.0      445507 2018-01-01 09:07:00
# 18                   0.0      445507 2018-01-01 03:25:00
# 19                   0.0      445507 2018-01-01 03:26:00
# 20                   0.0      445507 2018-01-01 03:30:00
# 21                   0.0      445507 2018-01-01 04:17:00
# 22                   0.0      445507 2018-01-01 04:53:00
# 23                  16.0      445507 2018-01-01 07:24:00
# 24                   0.0      445507 2018-01-01 05:42:00
# 25                   0.0      445507 2018-01-01 06:05:00
# 26                  18.0      445507 2018-01-01 11:54:00
# 27                   0.0      445507 2018-01-01 06:07:00
# 28                  19.0      445507 2018-01-01 08:37:00
# 29                   0.0      445507 2018-01-01 06:08:00
# 30                   0.0      445507 2018-01-01 06:08:00
# 31                   0.0      445507 2018-01-01 06:32:00
# ..                   ...         ...                 ...
# 122                 66.0      574823 2019-09-09 13:18:00
# 123                 66.0      574823 2019-09-09 13:21:00
# 124                 66.0      574823 2019-09-09 13:22:00
# 125                 66.0      574823 2019-09-09 13:24:00
# 126                 66.0      574823 2019-09-09 13:26:00
# 127                 66.0      574823 2019-09-09 13:31:00
# 128                 66.0      574823 2019-09-09 13:49:00
# 129                 66.0      574823 2019-09-09 14:19:00
# 130                 66.0      574823 2019-09-09 14:20:00
# 131                 66.0      574823 2019-09-09 13:37:00
# 132                  0.0      574823 2019-09-09 13:17:00
# 133                  0.0      574823 2019-09-09 13:18:00
# 134                 71.0      574823 2019-09-09 16:53:00
# 135                  0.0      574823 2019-09-09 13:25:00
# 136                  0.0      574823 2019-09-09 13:28:00
# 137                 84.0      574823 2019-09-09 16:45:00
# 138                  0.0      574823 2019-09-09 13:36:00
# 139                 91.0      574823 2019-09-09 13:39:00
# 140                  0.0      574823 2019-09-09 13:39:00
# 141                 96.0      574823 2019-09-09 13:40:00
# 142                  0.0      574823 2019-09-09 13:41:00
# 144                101.0      574823 2019-09-09 17:35:00
# 145                  0.0      574823 2019-09-09 13:46:00
# 146                  0.0      574823 2019-09-09 13:56:00
# 147                105.0      574823 2019-09-09 13:57:00
# 148                  0.0      574823 2019-09-09 14:30:00
# 149                114.0      574823 2019-09-09 14:58:00
# 150                  0.0      574823 2019-09-09 14:55:00
# 151                116.0      574823 2019-09-09 14:56:00
# 152                  0.0      574823 2019-09-09 18:19:00
#
#                                         clean_comments  \
# 0    מנהיג צפון קוריאה כפתור גרעיני הותקן בשולחן הע...
# 1    ככה זה קים מזמין הפצצה גרעינית וטראמפ מזמין רק...
# 2                       עכשיו צריך רק להפציץ את השולחן
# 3                                                גדולל
# 4                                                 חחחח
# 5    בעבר היו מטורפים שניסו וגם הצליחו להשמיד עמים ...
# 7                                          שכחת צוללות
# 9                                לא הייתי מזלזל בצוללת
# 10   אתה חושב שפצצה אחת תשמיד את אמריקה מקסימום ימו...
# 11                            לא להשמדה פיזית התכוונתי
# 12            כל עוד זה לא הותקן בשירותים שלו אני רגוע
# 13                                                 חחח
# 14                          האיומים המאוד נקודתיים שלו
# 15   לא הציג יכולות הטיל האחרון ששיגר הוכח כיכול לה...
# 16   בדיוק ברור הרי שללא קייס ארה ב היתה כבר אחרי ס...
# 17   יש הבדל גדול בין פיצוץ מתקן גרעיני במנהרה לבין...
# 18                                               בדיחה
# 19                 מזכיר את דוקטור evil מאוסטין פווארס
# 20                                  שולחן העבודה במחשב
# 21                                                 הנה
# 22   לא רק איומים קים מאחל הצלחה לאולימפידאת הנכים ...
# 23   ברור שיתמוך בנכים הטילים שישגר יהרגו מיליונים ...
# 24                                          אפשר תמונה
# 25    שלא יתבלבל בין הכפתור של lunch והכפתור של launch
# 26                                            חחח יפהה
# 27                                               טיפקס
# 28                                   גם לי זה עלה לראש
# 29    מקווה שיש לו מצב נעילת שולחן כשהוא יוצא מהבית חח
# 30   לפי איך שהוא נראה ראוי שישים את הכפתור בשולחן ...
# 31                     משוגע משוגע אבל עדיף להזהר ממנו
# ..                                                 ...
# 122                                גם זה הרבה יותר מדי
# 123                     לא רלווטי אם הוא יקבל 5 6 או 7
# 124  לא מאמין שיש ימני אמיתי שביום הבוחר מאחורי הפרגוד
# 125              פסיכולוגיה בגרוש נתניהו לא ימין עובדה
# 126                צודק גנץ ימין לפיד ימין ליברמן ימין
# 127                 מה זה ימין שפוי ומה זה ימין קיצוני
# 128                         אני בעד יד קשה מול האויבים
# 129                         ואתה מצביע למי נתניהו חחחח
# 130                      ליכוד ימינה אפילו יהדות התורה
# 131  מי שמכיר את השטח ויוצאי חבר העמים מבין שהוא מג...
# 132  בוגר וקסנר נעדר מעניין אם קיבל הוראה מהבוסים ל...
# 133  למכירה מצלמות לצילום בקלפיות חדשות באריזה לפרט...
# 134  זה אף פעם לא ב נ עצמו זה תמיד בן דוד או מקורב ...
# 135                           ככה זה כשלא יודעים לשלוט
# 136                                  אם למישהו היה ספק
# 137                                 לא ברור לי הקו הזה
# 138                                    קארמה איז א ביץ
# 139                                                אכן
# 140  ליברמן שלשום תמך בחוק היום מתנגד קשקשן מארץ הק...
# 141                     מקביל ל אשקול את הנושא של ביבי
# 142                                       הו הא מה קרה
# 144  מטרתו לגרום להתכתשות שתעביר תעמולת הזייפנים נו...
# 145                                 ערוץ הבידור ובחינם
# 146  ראיתי את הפרצופים המעצבנים בוועדה המסדרת של חכ...
# 147                                          חחח אשריך
# 148                                       טרגדיה ענקית
# 149                                  התכוונת לכחול לבן
# 150  נתניהו נושם לרווחה הוא לא באמת רוצה את החוק כי...
# 151  סוף סוף תגובה רצינית הכל היה פרובוקציה כדי ששו...
# 152                        צר לי שפולקמן עוזב איש ערכי
#
#                                    clean_comments_body comment_to_name  \
# 0    מנהיג צפון קוריאה קים ג ון און מתפאר שבשולחן ה...             nan
# 1                                                                 Mr W
# 2                                                                 Mr W
# 3                                                                  joe
# 4                                                                  joe
# 5    אבל המטורף השמן הזה מצפון קוריאה עולה על כולם ...            Mr W
# 7    או ליתר דיוק צוללת אחת לפי הפורסם שגם אותה לא ...    News just in
# 9    בפרט אם היא בקטע של משימה חד פעמית קמיקאזהלגבי...    News just in
# 10   במדבר י ג ל ג ונהי בעינינו כחגבים וכן היינו בע...      צבי_ישראל#
# 11   יותר לעידן של פחד וחששותבדיוק כמו שאירופה עברה...        SpinozaB
# 12                                                                Mr W
# 13                                    אכן עצירות הורגת       Reflektor
# 14   עם צורה ועם הרבה צבע מעלים את הסבירות כי אין מ...            Mr W
# 15   מצביעות בוודאות על יכולת גרעינית גם פצצות מימן...     intelligent
# 16                                                        להכות בברזל#
# 17                                                        להכות בברזל#
# 18                                   ליצן חצר לא מוצלח            Mr W
# 19   עוד רגע הוא מאיים שאם לא יתנו לו מיליון דולר ה...            Mr W
# 20                                 בטח יש לו חלונות 95            Mr W
# 21                                                                Mr W
# 22   הרודן אמר בנוסף שהוא ישתמש בגרעין רק במידה וצפ...            Mr W
# 23   לכל חייהם אז כדי להקדים תרופה למכה הוא תומך בא...     NowsTheTime
# 24                                                                Mr W
# 25                                                                Mr W
# 26                                                             dilbert
# 27                            לחץ כאן לצפיה דרך יוטיוב            Mr W
# 28                                                          פרה אדומה#
# 29   באמת פסיכופת מושלם האיש הקטןבעולם מתוקן הוא ומ...            Mr W
# 30                                                                Mr W
# 31                            לחץ כאן לצפיה דרך יוטיוב            Mr W
# ..                                                 ...             ...
# 122      במבט לאחור חוכמה בדיעבד זה בעצם דבר נורא טפשי             Idf
# 123  אלא כמה מצביעי שמאל וכמה ימין הוא יגנוב כרגע ה...             Idf
# 124  ישלשל פתק של ליברמן בידיעה שהוא מקבל ממשלת שמא...        Reddish#
# 125                                צ ד ק צ ד ק ת ר ד ף             Idf
# 126  ובן גביר ראש הממשלה הבא או לנו עם אחד כמו בן ג...        קפטן הוק
# 127  מה שפוי בימין שאתה מייצגזה מענייןאתה בעד מסירת...             Idf
# 128  אני בעד למצוא פתרון למסתננים אני בעד למצוא פית...          yansop
# 129                                צ ד ק צ ד ק ת ר ד ף             Idf
# 130                              רק לא לבן גביר ולהקתו        קפטן הוק
# 131  אבל למה להרוס את כל הכיף תן לשמאל להתבשם בשטוי...             Idf
# 132  אין לנו ארץ אחרת מדינת ישראל תישאר יהודית ודמו...        gold1980
# 133                            תתמודדו הפועל יש רק אחת        gold1980
# 134  הנה תראו איש משתגע למה תביאו אותו אליי חסר משו...           em28#
# 135                                                           gold1980
# 136  ליברמן טיבי לפיד בשיתוף פעולהליברמן בגוש השמאל...        gold1980
# 137  מה גורם לכם לחשוב שמצביעי ליברמן עילגים עד כדי...         pure_sp
# 138                                                           gold1980
# 139  ויש לך ניק מאד מאד מקורי ואם נחרבנו ונחרב העול...   הא כספא עניא#
# 140            we are fed up with being ruled by goyim        gold1980
# 141                                                              BEBO#
# 142                          הגוש הימני ציוני אכל אותה        gold1980
# 144  סביר שלא חשוב שהצעת החוק תעבור רק הרעש התקשורת...          lomyko
# 145                                                           gold1980
# 146                                                           gold1980
# 147                      כמו לראות את זיו השכינה תענוג           יואב#
# 148                           להיתקע עם מלאי של מצלמות        gold1980
# 149  כי הליכוד דיבר על תיעוד טלפוני אגב בבחירות הקו...      יגאל פת-אל
# 150                                                           gold1980
# 151    הפתרון ההומאני לתושבי עזה חיים נוחים באינדונזיה       dave2000#
# 152                                                           gold1980
#
#     original_comment_to_name
# 0                       Mr W
# 1                       Mr W
# 2                       Mr W
# 3                        joe
# 4                        joe
# 5                       Mr W
# 7                   Starback
# 9                   Starback
# 10                  Starback
# 11                  Starback
# 12                      Mr W
# 13                 Reflektor
# 14                      Mr W
# 15               intelligent
# 16               intelligent
# 17               intelligent
# 18                      Mr W
# 19                      Mr W
# 20                      Mr W
# 21                      Mr W
# 22                      Mr W
# 23               NowsTheTime
# 24                      Mr W
# 25                      Mr W
# 26                   dilbert
# 27                      Mr W
# 28                פרה אדומה#
# 29                      Mr W
# 30                      Mr W
# 31                      Mr W
# ..                       ...
# 122                      Idf
# 123                      Idf
# 124                      Idf
# 125                      Idf
# 126                      Idf
# 127                      Idf
# 128                      Idf
# 129                      Idf
# 130                      Idf
# 131                      Idf
# 132                 gold1980
# 133                 gold1980
# 134                    em28#
# 135                 gold1980
# 136                 gold1980
# 137                  pure_sp
# 138                 gold1980
# 139            הא כספא עניא#
# 140                 gold1980
# 141                    BEBO#
# 142                 gold1980
# 144                   lomyko
# 145                 gold1980
# 146                 gold1980
# 147                    יואב#
# 148                 gold1980
# 149               יגאל פת-אל
# 150                 gold1980
# 151                dave2000#
# 152                 gold1980
#
# [1918611 rows x 15 columns]

# %%
df2['clean_comments_body_no_signature'] = df2.apply(lambda x: x["clean_comments_body"].replace(x["maybe_signature"], "").strip(), axis=1)

# %% [markdown]
# <p> Now I will concatenate the comment body and the header</p>

# %%
df2['all_text_clean']=df2['clean_comments']+' '+df2['clean_comments_body_no_signature']

# %%
pd.to_pickle(df2,'/data/nlp_proj/all_comments_per_writer_df_with_hash_with_cleaning_signature.pkl' )

# %% [markdown]
# <p> In order to apply the LDA, I will concatenate all the text from each user, after all the preprocessing </p>

# %%
grouped_by_user=df2.groupby('name')['all_text_clean'].apply(lambda x: "%s" % ' '.join(x)).reset_index()

# %%
grouped_by_user['all_text_clean']=grouped_by_user['all_text_clean'].str.split()

# %%
grouped_by_user.head(10)
# Out:
#          name                                     all_text_clean
# 0     -השומר-  [מן, הסתם, זה, סקוטצ, אתמול, היה, טוב, ויהיה, ...
# 1    -השומר-#  [נשמע, היטב, אתמול, היה, טוב, ויהיה, גם, מחר, ...
# 2   -ירושלמי-  [תסבירו, לה, שכבר, בשנות, ה80, היו, עושים, את,...
# 3  -ירושלמי-#  [אכב, לא, יודע, אם, משהו, שם, לב, לאן, נעלמו, ...
# 4         007  [חכה, חצי, שעה, ערוץ, 13, גל, תקיפות, נוסף, אש...
# 5        007#  [פוש, עימותים, קשים, במקום, פוש, מצריך, פוש, ל...
# 6    09meir09  [מקווה, שהם, הסכימו, לרחוץ, רגליים, לפני, מה, ...
# 7   09meir09#  [טעות, לעזוב, את, רוסיה, גם, יש, לו, בשר, תותח...
# 8        1984  [חירטוטים, החוק, הבין, לאומי, קובע, שפליט, הוא...
# 9       1984#  [עונש, מוות, הוא, הדבר, הנכון, מוסרית, עונש, מ...

# %%
users=grouped_by_user['name']
texts=grouped_by_user['all_text_clean'].values

# %%
dictionary = Dictionary(texts)

# %%
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
for n_topics in [10,15,20]:
    for decay in [0.5, 0.7, 0.9]
        lda = LdaModel(corpus, num_topics=n_topics, decay=decay)
        lda_matrix=[lda[c] for c in corpus]
        i, j, data = zip(*((i, t[0], t[1]) for i, row in enumerate(lda_matrix) for t in row))
        dense_lda=csr_matrix((data, (i, j)), shape=(len(corpus), 10)).todense()
        df_lda=pd.DataFrame(dense_lda, index=users)
        sim=cosine_similarity(dense_lda)
        similarity_df=pd.DataFrame(sim, index=users, columns=users)
        original_columns=[c for c in similarity_df.columns if not c.endswith('#')]
        all_indexes2=[]
        original_names2=[]
        for o_c in tqdm(original_columns):
            try:
                curr_series=similarity_df[o_c]
                curr_series=similarity_df[o_c].sort_values(ascending=False)
                curr_index=curr_series.index.get_loc(o_c+'#')
                all_indexes2.append(curr_index)
                original_names2.append(o_c)
            except:
                print(o_c)
        similarity_series2=pd.Series(all_indexes2, index=original_names2)
        print("n topics:{0}\n decay:{1}\n mean rank:{2}".format(n_topics,decay,similarity_series2.mean()))

# %%
pickle.dump(lda,open('/data/nlp_proj/lda_model.pkl','wb'))

# %%
df_lda=pd.DataFrame(dense_lda, index=users)

# %%
df_lda.to_csv('/data/nlp_proj/cotextual_lda.csv', index=None)

# %%
# Out:
#  77%|███████▋  | 1807/2334 [00:02<00:00, 695.02it/s]
# כהן22
# 100%|██████████| 2334/2334 [00:03<00:00, 690.74it/s]

# %%
print("mean rank: {}".format(similarity_series2.mean()))
print("median rank: {}".format(similarity_series2.median()))
print("75% quantile: {}".format(similarity_series2.quantile(0.75)))
print("90% quantile: {}".format(similarity_series2.quantile(0.9)))
# Out:
# mean rank: 465.47149592798974
# median rank: 129.0
# 75% quantile: 568.0
# 90% quantile: 1438.4000000000005

# %%
similarity_series2.hist(bins=100,histtype='step')
plt.title('ranks distribution')
plt.xlabel('rank')
_=plt.ylabel('frequency')

# %% [markdown]
# <p> We see here that the results are far less good than in the word2vec model. It is still far better than the baseline, but the median jumped from 22 to 129.</p>
